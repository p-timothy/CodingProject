# %% [markdown]
# # Main area

# %%
import rasterio
from rasterio.plot import show
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rsgislib
import rsgislib.imagecalc
import rsgislib.imagecalc.calcindices
from rsgislib import imageutils
import rsgislib.imageutils
import rsgislib.rastergis

# %% [markdown]
# # Me

# %%
def ndvi(filepath):

    name = output + filepath[-15:-4] + '_ndvi' + filepath[-4:]
    rsgislib.imagecalc.calcindices.calc_ndvi(filepath, 3, 4, name, 
                                                    calc_stats=True, 
                                                    gdalformat='GTIFF')
    
    return(name)

# %%
# set an imput filepath for landsat images
imagepath = 'C:\\Users\\tschr\\Desktop\\Landsat\\Images\\'
#set an output filepath for ndvis, and sand and dune pixles
output = "C:\\Users\\tschr\\Desktop\\Landsat\\output\\"

#set lists for study area images
MC_n = []
MC_s = []
NB_n = []
NB_s = []
SJ_n = []
SJ_s = []


year = 100
for i in range(0,13):
    if year == 112:
        year = 184
    elif year == 192:
        year = 194
    MC_n.append(imagepath + 'MC_north_' + str(year)[-2:] + ".TIF")
    MC_s.append(imagepath + 'MC_south_' + str(year)[-2:] + ".TIF")
    NB_n.append(imagepath + 'NB_north_' + str(year)[-2:] + ".TIF")
    NB_s.append(imagepath + 'NB_south_' + str(year)[-2:] + ".TIF")
    SJ_n.append(imagepath + 'SJ_north_' + str(year)[-2:] + ".TIF")
    SJ_s.append(imagepath + 'SJ_south_' + str(year)[-2:] + ".TIF")
    year += 2

# %%
MC_n_ndvi = []
MC_s_ndvi = []
NB_n_ndvi = []
NB_s_ndvi = []
SJ_n_ndvi = []
SJ_s_ndvi = []


for i in range(0,13):
    MC_n_ndvi.append(ndvi(MC_n[i]))
    MC_s_ndvi.append(ndvi(MC_s[i]))
    NB_n_ndvi.append(ndvi(NB_n[i]))
    NB_s_ndvi.append(ndvi(NB_s[i]))
    SJ_n_ndvi.append(ndvi(SJ_n[i]))
    SJ_s_ndvi.append(ndvi(SJ_s[i]))
    
filelist = [MC_n_ndvi, MC_s_ndvi, NB_n_ndvi, 
            NB_s_ndvi, SJ_n_ndvi, SJ_s_ndvi]

# %%
ndvilist = [MC_n_ndvi, MC_s_ndvi, NB_n_ndvi,
            NB_s_ndvi, SJ_n_ndvi, SJ_s_ndvi ]

sandDuneList = [[],[],[],[],[],[]]
listIndex = 0

for i in filelist:
    year = 100
    for o in i:
        if year == 112:
            year = 184
        elif year == 192:
            year = 194
        
        name = output + o[-20:-9] + '_sandAndDune_' + str(year)[-2] + o[-4:]
        sandDuneList[listIndex].append(name)
        
        band_defns = [rsgislib.imagecalc.BandDefn("ndvi", o, 1)]   
        exp = 'ndvi<-0.039?0:ndvi<=0.04?1:ndvi<0.05?0:ndvi>=0.25?0:2'
        rsgislib.imagecalc.band_math(name, exp, "GTIFF", 
                                         rsgislib.TYPE_8UINT, band_defns)
        rsgislib.imageutils.pop_thmt_img_stats(name,True,0.,True)
        year += 2
        
    listIndex += 1
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 87.27it/s]

# %%
year = 1984
d = pd.DataFrame({'TotalPixles':[], 'SandPixles':[], 'DunePixles':[], 'BothPixles':[], 
                  'BeachPixlesPercent':[], 'DunePixlesPercent':[], 'BothPixlesPercent':[]})

for i in sandDuneList:
    
    for o in i:
        if o[-20] == '0' or o[-20] == '1':
            year = '20' + o[-20:-18]
        else:
            year = '19' + o[-20:-18]            
        src = rasterio.open(o)
        srcRead = src.read(1)
        unique, counts = np.unique(srcRead, return_counts=True)
        if year == 1992:
            year = 1994
        d.loc[o[-29:-20] + '_' + str(year)] = [counts[0], counts[1], counts[2], counts[1] + counts[2], 
                             (counts[1] / counts[0])*100, (counts[2] / counts[0])*100, 
                             ((counts[1] + counts[2]) / counts[0] )*100]

# %%
d.head()
# Out:
#                 TotalPixles  SandPixles  DunePixles  BothPixles  \
# MC_north__2000      15865.0       265.0       226.0       491.0
# MC_north__2002      15862.0       240.0       254.0       494.0
# MC_north__2004      15840.0       249.0       267.0       516.0
# MC_north__2006      15788.0       319.0       249.0       568.0
# MC_north__2008      15778.0       274.0       304.0       578.0
#
#                 BeachPixlesPercent  DunePixlesPercent  BothPixlesPercent
# MC_north__2000            1.670344           1.424519           3.094863
# MC_north__2002            1.513050           1.601311           3.114361
# MC_north__2004            1.571970           1.685606           3.257576
# MC_north__2006            2.020522           1.577147           3.597669
# MC_north__2008            1.736595           1.926733           3.663329

# %% [markdown]
# # Not me

# %% [markdown]
# # Also, Not me
