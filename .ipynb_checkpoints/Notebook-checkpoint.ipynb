# %% [markdown]
# # Main area

# %%
import rasterio
from rasterio.plot import show
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rsgislib
import rsgislib.imagecalc
import rsgislib.imagecalc.calcindices
from rsgislib import imageutils
import rsgislib.imageutils
import rsgislib.rastergis

# %% [markdown]
# ### Variables

# %%
filepath = ''
output = ''

# %% [markdown]
# # Me

# %%
# set an imput filepath for landsat images
imagepath = 'C:\\Users\\tschr\\Desktop\\Landsat\\Images\\'
#set an output filepath for ndvis, and sand and dune pixles
output = "C:\\Users\\tschr\\Desktop\\Landsat\\output\\"

#set lists for study area images
beach = []

year = 1986
for i in range(0,12):
    if year == 1992:
        year += 2
    beach.append(imagepath + str(year) + ".TIF")
    year += 2

# %%
beach_ndvi = []

for i in range(0,12):
    
    name = output + beach[i][-8:-4] + '_ndvi' + beach[i][-4:]
    rsgislib.imagecalc.calcindices.calc_ndvi(beach[i], 3, 4, name, 
                                                    calc_stats=True, 
                                                    gdalformat='GTIFF')
    
    beach_ndvi.append(name)

# %%
sandDuneList = []

for i in beach_ndvi:

    name = output + i[-13:-9] + '_sandAndDune' + i[-4:]
    sandDuneList.append(name)
        
    band_defns = [rsgislib.imagecalc.BandDefn("ndvi", i, 1)]   
    exp = 'ndvi<-0.039?0:ndvi<=0.04?1:ndvi<0.05?0:ndvi>=0.25?0:2'
    rsgislib.imagecalc.band_math(name, exp, "GTIFF", 
                                        rsgislib.TYPE_8UINT, band_defns)
    rsgislib.imageutils.pop_thmt_img_stats(name,True,0.,True)
    year += 2
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 38.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 54.44it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 76.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 60.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 69.80it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 83.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 50.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 77.14it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 65.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 66.71it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 81.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 63.75it/s]

# %%
d = pd.DataFrame({'year': [],'TotalPixles':[], 'SandPixles':[], 'DunePixles':[], 'BothPixles':[], 
                  'BeachPixlesPercent':[], 'DunePixlesPercent':[], 'BothPixlesPercent':[]})

year = 1986
for i in sandDuneList:
    if year == 1992:
        year += 2
    src = rasterio.open(i)
    srcRead = src.read(1)
    unique, counts = np.unique(srcRead, return_counts=True)
    d.loc[i[-20:-16]] = [year, counts[0], counts[1], counts[2], counts[1] + counts[2], 
                        (counts[1] / counts[0])*100, (counts[2] / counts[0])*100, 
                        ((counts[1] + counts[2]) / counts[0] )*100]
    year += 2

# %%
d.head(13)
# Out:
#         year  TotalPixles  SandPixles  DunePixles  BothPixles  \
# 1986  1986.0    2084747.0      1572.0      3148.0      4720.0
# 1988  1988.0    2083108.0      2304.0      4055.0      6359.0
# 1990  1990.0    2083992.0      2122.0      3353.0      5475.0
# 1994  1994.0    2084036.0      1881.0      3550.0      5431.0
# 1996  1996.0    2084124.0      1805.0      3538.0      5343.0
# 1998  1998.0    2084304.0      1783.0      3380.0      5163.0
# 2000  2000.0    2083460.0      2733.0      3274.0      6007.0
# 2002  2002.0    2083320.0      2388.0      3759.0      6147.0
# 2004  2004.0    2083140.0      2493.0      3834.0      6327.0
# 2006  2006.0    2082218.0      2940.0      4309.0      7249.0
# 2008  2008.0    2082975.0      2462.0      4030.0      6492.0
# 2010  2010.0    2083592.0      2265.0      3610.0      5875.0
#
#       BeachPixlesPercent  DunePixlesPercent  BothPixlesPercent
# 1986            0.075405           0.151002           0.226406
# 1988            0.110604           0.194661           0.305265
# 1990            0.101824           0.160893           0.262717
# 1994            0.090258           0.170343           0.260600
# 1996            0.086607           0.169760           0.256367
# 1998            0.085544           0.162164           0.247709
# 2000            0.131176           0.157142           0.288318
# 2002            0.114625           0.180433           0.295058
# 2004            0.119675           0.184049           0.303724
# 2006            0.141196           0.206943           0.348138
# 2008            0.118196           0.193473           0.311670
# 2010            0.108707           0.173258           0.281965

# %%
fig, ax = plt.subplots(1,2, sharey=True)

ax[0].scatter(d['year'],d['SandPixles'])
ax[0].set_title('Year by Sand')
ax[1].scatter(d['year'],d['DunePixles'])
ax[1].set_title('Year by Dune')


plt.show()

# %% [markdown]
# # Not me

# %%
#years 1985-2001
storm85 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/85data.csv")
# read CSV files 2002-2020
storm1 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/storm_data_01-01-2000_12-31-2005.csv")
storm2 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/storm_data_01-01-2006_12-31-2009.csv")
storm3 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/storm_data_01-01-2010_12-31-2012.csv")
storm4 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/storm_data_01-01-2013_12-31-2017.csv")
storm5 = pd.read_csv("C:/Users/shaun/OneDrive/Documents/CodingData/storm_data_01-01-2018_12-31-2020.csv")
storm02 = pd.concat([storm1, storm2, storm3, storm4, storm5], axis=0)

# %%
# change first dataset index to year
storm85 = storm85.set_index('year')
# calculate number of events
storm85['number_events'] = storm85.sum(axis = 1)
#drop month columns
storm85 = storm85.drop(['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'], axis=1)

# %%
# change column names to match first dataset
storm02.rename(columns={'BEGIN_DATE':'year', 'EVENT_ID': 'number_events'}, inplace=True)
# change date type from object to datetime
storm02['year'] = pd.to_datetime(storm02.year, format='%m/%d/%Y')
# selects winds with magnitude over 50
mag = storm02['MAGNITUDE'] >= 50
storm02 = storm02[mag]
# count dataset events by year
storm02 = storm02.groupby(storm02.year.dt.year)['number_events'].count()
storm02 = pd.DataFrame(storm02)

# %%
storms = pd.concat([storm85,storm02], axis=0)

# %%
stormdataset = {'years': ['1985','1986-1990','1991-1995','1996-2000','2001-2005','2006-2010','2011-2015','2016-2020'],
               'number_events': [(storms.iloc[[0]].mean()['number_events']),(storms.iloc[[1,2,3,4,5]].mean()['number_events']),
                                 (storms.iloc[[6,7,8,9,10]].mean()['number_events']),(storms.iloc[[11,12,13,14,15]].mean()['number_events']),
                                 (storms.iloc[[16,17,18,19,20]].mean()['number_events']),(storms.iloc[[21,22,23,24,25]].mean()['number_events']),
                                 (storms.iloc[[26,27,28,29,30]].mean()['number_events']),(storms.iloc[[31,32,33,34,35]].mean()['number_events'])]}
stormdataset = pd.DataFrame(data=stormdataset)
stormdataset
# Out:
#        years  number_events
# 0       1985           17.0
# 1  1986-1990           26.0
# 2  1991-1995           27.4
# 3  1996-2000           35.4
# 4  2001-2005           30.2
# 5  2006-2010           34.2
# 6  2011-2015           20.6
# 7  2016-2020           18.0

# %%
stormdataset = stormdataset.drop(['years'], axis = 1)
stormdataset
# Out:
#    number_events
# 0           17.0
# 1           26.0
# 2           27.4
# 3           35.4
# 4           30.2
# 5           34.2
# 6           20.6
# 7           18.0

# %% [markdown]
# # Also, Not me

# %%
# Read precipitation dataset
precipitation_dt = pd.read_csv('C:/Users/Dalton/Desktop/School/Winter_2023/GIS_490/Final_proj/data/Precipitation_final.csv')
precipitation_dt.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1985  2.17  4.78  3.50  2.00  1.97  3.47  3.49  4.40  2.81  3.27  9.00
# 1  1986  1.78  2.22  2.17  1.94  3.70  4.85  5.24  2.42  5.61  2.93  3.96
# 2  1987  2.13  0.50  0.91  2.13  5.08  3.24  4.76  6.94  3.23  4.43  1.65
# 3  1988  2.73  2.36  3.38  3.50  1.38  2.05  2.77  3.75  1.90  5.74  5.97
# 4  1989  1.43  1.49  2.16  2.33  3.40  4.23  2.98  4.58  4.29  1.94  3.53
#
#     Dec  Annual
# 0  2.37   43.23
# 1  1.49   38.31
# 2  5.45   40.45
# 3  2.18   37.71
# 4  2.92   35.28

# %%
#array Testing

# %%
#array for precip

# %%
#get precip dt without 1985
remove1985_precip = precipitation_dt[precipitation_dt["Year"] != 1985]
remove1985_precip
# Out:
#     Year   Jan   Feb   Mar   Apr   May   Jun   Jul    Aug    Sep    Oct   Nov  \
# 1   1986  1.78  2.22  2.17  1.94  3.70  4.85  5.24   2.42   5.61   2.93  3.96
# 2   1987  2.13  0.50  0.91  2.13  5.08  3.24  4.76   6.94   3.23   4.43  1.65
# 3   1988  2.73  2.36  3.38  3.50  1.38  2.05  2.77   3.75   1.90   5.74  5.97
# 4   1989  1.43  1.49  2.16  2.33  3.40  4.23  2.98   4.58   4.29   1.94  3.53
# 5   1990  2.32  3.86  3.83  2.31  7.42  4.74  4.78   8.63   4.28   6.64  8.74
# 6   1991  2.02  1.76  4.00  5.39  5.94  1.08  0.75   4.17   4.14  10.13  5.01
# 7   1992  2.27  2.98  5.23  2.34  0.51  2.79  6.34   2.44   8.85   1.69  6.33
# 8   1993  3.83  1.16  4.45  5.08  2.64  9.55  3.33   4.04   7.53   4.44  3.48
# 9   1994  2.26  1.26  0.90  3.05  0.82  5.87  2.87   5.63   1.34   3.29  4.50
# 10  1995  2.76  1.60  2.42  3.97  3.42  4.00  4.15   4.54   1.04   3.98  4.51
# 11  1996  1.32  1.54  1.48  3.45  6.81  6.91  8.52   2.15   3.50   3.69  3.74
# 12  1997  2.54  4.61  2.53  2.38  4.15  5.64  3.59   5.45   2.13   2.03  3.11
# 13  1998  3.38  2.29  4.52  3.18  2.10  3.55  4.01   4.82   1.20   2.27  1.61
# 14  1999  4.27  1.97  1.55  5.97  1.74  3.52  4.22   3.91   0.99   1.60  1.78
# 15  2000  2.71  1.86  1.77  3.66  4.42  7.64  3.91   2.42   4.54   2.78  3.50
# 16  2001  1.41  3.99  1.53  3.86  3.85  5.03  4.27   5.57   3.68   9.13  2.60
# 17  2002  2.98  2.48  3.64  4.71  5.47  1.40  2.58   2.42   1.14   1.43  2.10
# 18  2003  2.09  0.79  2.06  2.43  5.85  2.22  4.56   1.86   2.43   2.68  4.00
# 19  2004  1.56  0.93  4.40  1.48  6.05  3.34  4.53   9.40   0.31   3.42  5.61
# 20  2005  5.48  3.31  1.87  1.43  1.12  2.93  3.98   3.76   2.86   2.21  2.43
# 21  2006  4.58  1.55  3.69  3.35  4.69  1.94  7.19   3.96   3.53   4.66  4.00
# 22  2007  4.14  1.74  1.96  5.35  2.92  2.20  5.99   9.74   1.40   4.18  2.80
# 23  2008  6.90  3.86  1.83  3.18  2.96  3.77  3.07   3.45  15.29   4.10  2.83
# 24  2009  1.70  5.81  5.64  4.19  2.99  4.54  4.14   4.03   1.41   7.32  1.15
# 25  2010  2.36  1.84  1.95  3.65  7.39  5.58  4.99   2.19   2.22   1.46  3.76
# 26  2011  2.03  2.47  1.89  6.65  7.21  4.69  3.19   2.49   3.67   5.00  3.87
# 27  2012  3.19  2.21  1.47  1.83  3.25  2.07  5.03   4.15   1.26   4.48  0.52
# 28  2013  4.42  2.32  1.68  6.32  3.18  7.86  1.99   4.29   2.24   5.02  3.49
# 29  2014  2.80  2.77  1.98  2.35  7.03  8.80  1.99   5.95   2.72   4.72  2.59
# 30  2015  1.66  1.69  0.62  2.60  4.99  6.12  3.82   2.77   3.58   1.45  2.89
# 31  2016  1.77  2.99  3.79  3.20  3.67  3.24  5.07  10.37   2.27   4.01  3.48
# 32  2017  3.73  2.96  4.26  5.21  5.06  2.95  4.40   1.41   2.58   9.30  3.04
# 33  2018  2.92  7.25  1.46  2.48  6.49  3.51  4.30   4.05   2.48   4.14  4.22
# 34  2019  2.04  2.33  3.94  5.51  7.44  5.18  1.74   2.63   9.19   5.08  2.02
# 35  2020  4.96  1.11  2.07  4.93  5.83  3.24  2.62   2.46   1.91   3.27  2.29
#
#      Dec  Annual
# 1   1.49   38.31
# 2   5.45   40.45
# 3   2.18   37.71
# 4   2.92   35.28
# 5   4.66   62.21
# 6   2.81   47.20
# 7   4.32   46.09
# 8   2.10   51.63
# 9   2.69   34.48
# 10  0.66   37.05
# 11  2.97   46.08
# 12  3.56   41.72
# 13  2.37   35.30
# 14  3.79   35.31
# 15  3.85   43.06
# 16  1.76   46.68
# 17  2.02   32.37
# 18  2.11   33.08
# 19  3.40   44.43
# 20  1.96   33.34
# 21  3.68   46.82
# 22  3.68   46.10
# 23  5.42   56.66
# 24  2.33   45.25
# 25  3.57   40.96
# 26  2.94   46.10
# 27  2.87   32.33
# 28  2.04   44.85
# 29  1.54   45.24
# 30  4.83   37.02
# 31  1.97   45.83
# 32  2.60   47.50
# 33  3.14   46.44
# 34  2.25   49.35
# 35  2.26   36.95

# %%
#only get the Annual precip column
remove1985_precip_mean = remove1985_precip["Annual"]
remove1985_precip_mean
# Out:
# 1     38.31
# 2     40.45
# 3     37.71
# 4     35.28
# 5     62.21
# 6     47.20
# 7     46.09
# 8     51.63
# 9     34.48
# 10    37.05
# 11    46.08
# 12    41.72
# 13    35.30
# 14    35.31
# 15    43.06
# 16    46.68
# 17    32.37
# 18    33.08
# 19    44.43
# 20    33.34
# 21    46.82
# 22    46.10
# 23    56.66
# 24    45.25
# 25    40.96
# 26    46.10
# 27    32.33
# 28    44.85
# 29    45.24
# 30    37.02
# 31    45.83
# 32    47.50
# 33    46.44
# 34    49.35
# 35    36.95
# Name: Annual, dtype: float64

# %%
#variable to mean of every N years
N = 5

# %%
#get an array for the mean every 5 years

array_precip = remove1985_precip_mean.values.reshape(-1, N).mean(1)
array_precip
# Out:
# array([42.792, 43.29 , 40.294, 37.98 , 47.158, 41.108, 45.214])

# %%
#end array for precip

# %%
#get value for 1985, in order to add to array

# %%
#get only data for 1985
only1985_precip = precipitation_dt[precipitation_dt["Year"] == 1985]
only1985_precip
# Out:
#    Year   Jan   Feb  Mar  Apr   May   Jun   Jul  Aug   Sep   Oct  Nov   Dec  \
# 0  1985  2.17  4.78  3.5  2.0  1.97  3.47  3.49  4.4  2.81  3.27  9.0  2.37
#
#    Annual
# 0   43.23

# %%
only1985_precip_mean = only1985_precip["Annual"]
only1985_precip_mean
# Out:
# 0    43.23
# Name: Annual, dtype: float64

# %%
#add the 1985 mean to the array : array_test    only1985_mean
full_array_precip = np.append(only1985_precip_mean, array_precip)
full_array_precip
# Out:
# array([43.23 , 42.792, 43.29 , 40.294, 37.98 , 47.158, 41.108, 45.214])

# %%
#end adding 1985 mean to array

# %%
#turnning the array into a df

# %%
#array into a df
new_precip_df = pd.DataFrame(full_array_precip, columns = ['5 year mean precip'])
new_precip_df
# Out:
#    5 year mean precip
# 0              43.230
# 1              42.792
# 2              43.290
# 3              40.294
# 4              37.980
# 5              47.158
# 6              41.108
# 7              45.214

# %%
#end making a dt for precip array

# %%
#create an array/dt with the years column

# %%
#create a year array
year_array = pd.array(['1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020'], dtype=int)
year_array
# Out:
# <PandasArray>
# [1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
# Length: 8, dtype: int32

# %%
#create a df with years
new_year_df = pd.DataFrame(year_array, columns = ['years'])
new_year_df
# Out:
#    years
# 0   1985
# 1   1990
# 2   1995
# 3   2000
# 4   2005
# 5   2010
# 6   2015
# 7   2020

# %%
#end making a df with years

# %%
#join year df with precip df

# %%
#join with concat : new_year_df    new_precip_df
concat_df = pd.concat([new_year_df, new_precip_df], axis=1)
concat_df
# Out:
#    years  5 year mean precip
# 0   1985              43.230
# 1   1990              42.792
# 2   1995              43.290
# 3   2000              40.294
# 4   2005              37.980
# 5   2010              47.158
# 6   2015              41.108
# 7   2020              45.214

# %%
#read in ice data

# %%
# Read ice dataset
ice_dt = pd.read_csv('C:/Users/Dalton/Desktop/School/Winter_2023/GIS_490/Final_proj/data/max_ice_coverage.csv')
ice_dt.head()
# Out:
#    year  cover    date
# 0  1985   41.3  23-Feb
# 1  1986   66.8  23-Feb
# 2  1987   20.0  21-Feb
# 3  1988   32.7   7-Feb
# 4  1989   30.9  19-Mar

# %%
#array for ice

# %%
#get ice dt without 1985
remove1985_ice = ice_dt[ice_dt["year"] != 1985]
remove1985_ice
# Out:
#     year  cover    date
# 1   1986   66.8  23-Feb
# 2   1987   20.0  21-Feb
# 3   1988   32.7   7-Feb
# 4   1989   30.9  19-Mar
# 5   1990   32.4  14-Jan
# 6   1991   21.5  30-Jan
# 7   1992   32.8   3-Feb
# 8   1993   32.2  28-Feb
# 9   1994   82.7  14-Feb
# 10  1995   21.6  13-Feb
# 11  1996   75.0   7-Feb
# 12  1997   37.8   5-Feb
# 13  1998   15.1   6-Feb
# 14  1999   23.0  15-Jan
# 15  2000   27.2  28-Jan
# 16  2001   29.5  22-Feb
# 17  2002   12.4   7-Mar
# 18  2003   48.0  10-Mar
# 19  2004   36.4   5-Feb
# 20  2005   29.4  24-Jan
# 21  2006   16.1  20-Feb
# 22  2007   37.2   8-Mar
# 23  2008   33.5  21-Feb
# 24  2009   52.3  29-Jan
# 25  2010   23.5   8-Feb
# 26  2011   29.4  11-Feb
# 27  2012   16.7  21-Jan
# 28  2013   24.4  18-Feb
# 29  2014   93.1   8-Mar
# 30  2015   72.9  27-Feb
# 31  2016   26.8  14-Feb
# 32  2017   18.2  18-Jan
# 33  2018   51.3  11-Feb
# 34  2019   55.8   8-Mar
# 35  2020   17.2  21-Feb

# %%
#only get the cover (Annual) ice column
remove1985_ice_mean = remove1985_ice["cover"]
remove1985_ice_mean
# Out:
# 1     66.8
# 2     20.0
# 3     32.7
# 4     30.9
# 5     32.4
# 6     21.5
# 7     32.8
# 8     32.2
# 9     82.7
# 10    21.6
# 11    75.0
# 12    37.8
# 13    15.1
# 14    23.0
# 15    27.2
# 16    29.5
# 17    12.4
# 18    48.0
# 19    36.4
# 20    29.4
# 21    16.1
# 22    37.2
# 23    33.5
# 24    52.3
# 25    23.5
# 26    29.4
# 27    16.7
# 28    24.4
# 29    93.1
# 30    72.9
# 31    26.8
# 32    18.2
# 33    51.3
# 34    55.8
# 35    17.2
# Name: cover, dtype: float64

# %%
#get an ice array for the mean every 5 years
array_ice_mean = remove1985_ice_mean.values.reshape(-1, N).mean(1)
array_ice_mean
# Out:
# array([36.56, 38.16, 35.62, 31.14, 32.52, 47.3 , 33.86])

# %%
#end array for ice

# %%
#get value for 1985, in order to add to array

# %%
#get only data for 1985
only1985_ice = ice_dt[ice_dt["year"] == 1985]
only1985_ice
# Out:
#    year  cover    date
# 0  1985   41.3  23-Feb

# %%
#get only cover
only1985_ice_mean = only1985_ice["cover"]
only1985_ice_mean
# Out:
# 0    41.3
# Name: cover, dtype: float64

# %%
#add the 1985 ice mean to the ice array : array_ice_mean    only1985_ice_mean
full_ice_array = np.append(only1985_ice_mean, array_ice_mean)
full_ice_array
# Out:
# array([41.3 , 36.56, 38.16, 35.62, 31.14, 32.52, 47.3 , 33.86])

# %%
#end adding 1985 ice mean to array

# %%
#turnning the ice array into a df

# %%
#ice array into an ice df
new_ice_df = pd.DataFrame(full_ice_array, columns = ['5 year mean ice'])
new_ice_df
# Out:
#    5 year mean ice
# 0            41.30
# 1            36.56
# 2            38.16
# 3            35.62
# 4            31.14
# 5            32.52
# 6            47.30
# 7            33.86

# %%
#end making a dt for precip array

# %%
#join concat_df df with ice df

# %%
#join with concat : new_year_df    new_precip_df
final_concat_df = pd.concat([concat_df, new_ice_df], axis=1)
final_concat_df
# Out:
#    years  5 year mean precip  5 year mean ice
# 0   1985              43.230            41.30
# 1   1990              42.792            36.56
# 2   1995              43.290            38.16
# 3   2000              40.294            35.62
# 4   2005              37.980            31.14
# 5   2010              47.158            32.52
# 6   2015              41.108            47.30
# 7   2020              45.214            33.86

# %%
#end concat of df

# %%
#start histograms

# %%
# Plot histogram: will need to adjust bins
final_concat_df_hist = final_concat_df.hist(bins=8 , figsize=(20, 10))

# %%
#end histogram

# %%
#start cor. mat.

#need to replace cor. value withcolumn heads

# %%
# Compute correlation matrix
dune_corr_matrix = final_concat_df.corr()

# Display just dune value correlations
#replace years with dune
dune_corr_matrix["years"].sort_values(ascending= False)
# Out:
# years                 1.000000
# 5 year mean precip    0.150289
# 5 year mean ice      -0.110057
# Name: years, dtype: float64

# %%
# Compute correlation matrix
beach_corr_matrix = final_concat_df.corr()

# Display just beach value correlations
beach_corr_matrix["beach"].sort_values(ascending= False)

# %%
# Compute correlation matrix
beach_and_dune_corr_matrix = final_concat_df.corr()

# Display just dune value correlations
beach_and_dune_corr_matrix["beach and dune"].sort_values(ascending= False)

# %%
#end cor. mat.

# %%
#start regresion

# all features will need to be updated

# %%
# Import library
from sklearn.preprocessing import StandardScaler

# Define feature list
feature_list =  ['precip', 'ice', 'storm', 'water']

# Define features and labels 
X = final_concat_df[feature_list]
y = final_concat_df['dune']

# %%
# Standarize data
scaler = StandardScaler()  
X_scaled = scaler.fit_transform(X)
final_dt_rough_scaled = pd.DataFrame(X_scaled, columns=feature_list)
final_dt_rough_scaled

# %%
from sklearn.model_selection import train_test_split

# Split data 
X_train, X_test, y_train, y_test = train_test_split(final_dt_rough_scaled, y, test_size=0.5, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Define model
lin_reg = LinearRegression()

# Fit model to data
lin_reg.fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error

# Predict test labels
predictions = lin_reg.predict(X_test)

# Compute mean-squared-error
lin_mse = mean_squared_error(y_test, predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse

# %%
# Plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(y_test, predictions, alpha=0.1, s=50, zorder=2)
ax.plot([0,100], [0, 100], color='k', lw=1, zorder=3)
ax.set_ylabel('Predicted dune change', fontsize=14)
ax.set_xlabel('Observed dune change', fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=13)
ax.grid(ls='dashed', lw=1, zorder=1)
ax.set_ylim(0,100)
ax.set_xlim(0,100)

# %% [markdown]
# # GABAGOO
